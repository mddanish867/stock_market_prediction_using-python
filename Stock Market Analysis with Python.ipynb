# %% [markdown]
# # Step 1: Importing Datasets

# %%
import pandas as pd
intc=pd.read_csv('INTC.csv')

# %%
intc=pd.read_csv('INTC.csv', header=0, index_col='Date', parse_dates=True)
intc
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2020-08-03  48.270000  48.630001  47.740002  48.299999  47.050617  31767100
# 2020-08-04  48.599998  49.139999  48.500000  49.130001  47.859154  29045800
# 2020-08-05  49.720001  49.720001  48.660000  48.919998  47.654583  29438600
# 2020-08-06  48.790001  48.820000  48.099998  48.570000  47.634968  23795500
# 2020-08-07  48.529999  48.650002  47.700001  48.029999  47.105358  36765200
# ...               ...        ...        ...        ...        ...       ...
# 2021-07-27  53.119999  53.200001  52.310001  53.180000  53.180000  39878000
# 2021-07-28  53.029999  53.919998  52.939999  53.070000  53.070000  28478800
# 2021-07-29  53.480000  54.099998  53.320000  53.700001  53.700001  16886600
# 2021-07-30  53.650002  53.900002  53.250000  53.720001  53.720001  16460000
# 2021-08-02  53.990002  54.470001  53.540001  53.680000  53.680000  18089400
#
# [252 rows x 6 columns]

# %%
intc.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2020-08-03  48.270000  48.630001  47.740002  48.299999  47.050617  31767100
# 2020-08-04  48.599998  49.139999  48.500000  49.130001  47.859154  29045800
# 2020-08-05  49.720001  49.720001  48.660000  48.919998  47.654583  29438600
# 2020-08-06  48.790001  48.820000  48.099998  48.570000  47.634968  23795500
# 2020-08-07  48.529999  48.650002  47.700001  48.029999  47.105358  36765200

# %%
intc.tail()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2021-07-27  53.119999  53.200001  52.310001  53.180000  53.180000  39878000
# 2021-07-28  53.029999  53.919998  52.939999  53.070000  53.070000  28478800
# 2021-07-29  53.480000  54.099998  53.320000  53.700001  53.700001  16886600
# 2021-07-30  53.650002  53.900002  53.250000  53.720001  53.720001  16460000
# 2021-08-02  53.990002  54.470001  53.540001  53.680000  53.680000  18089400

# %% [markdown]
# # using Pandas Data Reader

# %%
# !pip install pandas_datareader
# Out:
# ...
# WARNING: You are using pip version 20.3.3; however, version 21.2.2 is available.
# You should consider upgrading via the 'c:\users\lenovo\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install pandas-datareader
# Out:
# ...
# WARNING: You are using pip version 20.3.3; however, version 21.2.2 is available.
# You should consider upgrading via the 'c:\users\lenovo\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.
# ...

# %%
conda install -c conda-forge pandas-datareader
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Lenovo\anaconda3
#
#   added / updated specs:
#     - pandas-datareader
#
#
# Note: you may need to restart the kernel to use updated packages.
# The following NEW packages will be INSTALLED:
#
#   python_abi         conda-forge/win-64::python_abi-3.8-2_cp38
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   conda              pkgs/main::conda-4.10.3-py38haa95532_0 --> conda-forge::conda-4.10.3-py38haa244fe_0
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
conda update -n base -c defaults conda
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Lenovo\anaconda3
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be REMOVED:
#
#   python_abi-3.8-2_cp38
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   conda              conda-forge::conda-4.10.3-py38haa244f~ --> pkgs/main::conda-4.10.3-py38haa95532_0
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas_datareader as pdr
import datetime

# %%
nvda=pdr.get_data_yahoo('NVDA',
                       start=datetime.datetime(2004,1,1),
                       end=datetime.datetime(2021,8,2))
nvda.head()
# Out:
#                 High       Low      Open     Close       Volume  Adj Close
# Date
# 2003-12-31  1.987500  1.901667  1.978333  1.933333   49726800.0   1.776510
# 2004-01-02  1.990833  1.923333  1.964167  1.923333   43641600.0   1.767321
# 2004-01-05  1.999167  1.935000  1.952500  1.985833   57529200.0   1.824752
# 2004-01-06  2.094167  1.970833  1.980000  2.066667  109334400.0   1.899029
# 2004-01-07  2.095000  2.029167  2.043333  2.085000   67303200.0   1.915875

# %%
qcom=pdr.get_data_yahoo('QCOM',
                       start=datetime.datetime(2004,1,1),
                       end=datetime.datetime(2021,8,2))
qcom.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2003-12-31  27.400000  26.799999  27.305000  26.965000   9920200.0  18.537983
# 2004-01-02  27.495001  26.665001  27.010000  26.809999  13705000.0  18.431419
# 2004-01-05  27.445000  26.709999  26.750000  27.375000  15907200.0  18.819853
# 2004-01-06  27.415001  26.875000  27.235001  27.115000  16162600.0  18.641108
# 2004-01-07  28.115000  26.965000  27.000000  27.879999  20298600.0  19.167030

# %%
amd=pdr.get_data_yahoo('AMD',
                       start=datetime.datetime(2004,1,1),
                       end=datetime.datetime(2021,8,2))
amd.head()
# Out:
#              High    Low   Open  Close    Volume  Adj Close
# Date
# 2003-12-31  15.20  14.81  15.20  14.90   7395900      14.90
# 2004-01-02  15.11  14.77  15.10  14.86   8220700      14.86
# 2004-01-05  15.27  15.01  15.05  15.20   9156000      15.20
# 2004-01-06  15.82  15.05  15.21  15.61  14592200      15.61
# 2004-01-07  15.99  15.49  15.78  15.66  15329300      15.66

# %%
ibm=pdr.get_data_yahoo('IBM',
                       start=datetime.datetime(2004,1,1),
                       end=datetime.datetime(2021,8,2))
ibm.head()
# Out:
#                  High        Low       Open      Close     Volume  Adj Close
# Date
# 2003-12-31  92.849998  92.160004  92.660004  92.680000  4726900.0  59.020363
# 2004-01-02  93.050003  91.199997  92.860001  91.550003  5327800.0  58.300804
# 2004-01-05  93.089996  92.000000  92.000000  93.050003  5276300.0  59.255989
# 2004-01-06  93.190002  92.139999  92.199997  93.059998  4380000.0  59.262367
# 2004-01-07  93.379997  92.470001  93.139999  92.779999  4927600.0  59.084034

# %%
ibm.describe()
# Out:
#               High          Low         Open        Close        Volume  \
# count  4427.000000  4427.000000  4427.000000  4427.000000  4.427000e+03
# mean    137.865645   135.730924   136.751602   136.818191  5.610263e+06
# std      36.614756    36.384016    36.505285    36.502278  3.099661e+06
# min      73.690002    69.500000    72.529999    71.739998  1.027500e+06
# 25%     107.465000   104.895000   106.309998   106.255001  3.630150e+06
# 50%     136.889999   135.050003   135.979996   135.970001  4.799700e+06
# 75%     163.940002   161.695000   162.739998   162.720001  6.605650e+06
# max     215.899994   214.300003   215.380005   215.800003  3.806350e+07
#
#          Adj Close
# count  4427.000000
# mean    104.430484
# std      32.324108
# min      46.299591
# 25%      71.608574
# 50%     117.445740
# 75%     130.341866
# max     157.775299

# %%
amd.describe()
# Out:
#               High          Low         Open        Close        Volume  \
# count  4427.000000  4427.000000  4427.000000  4427.000000  4.427000e+03
# mean     17.178057    16.513921    16.858466    16.850043  3.298182e+07
# std      20.589612    19.851118    20.238790    20.241489  3.033810e+07
# min       1.690000     1.610000     1.620000     1.620000  0.000000e+00
# 25%       4.255000     4.085000     4.185000     4.170000  1.360895e+07
# 50%       9.380000     9.020000     9.160000     9.150000  2.285610e+07
# 75%      20.330000    19.405001    19.925000    19.900000  4.219810e+07
# max     110.330002   103.830002   105.930000   108.629997  3.250584e+08
#
#          Adj Close
# count  4427.000000
# mean     16.850043
# std      20.241489
# min       1.620000
# 25%       4.170000
# 50%       9.150000
# 75%      19.900000
# max     108.629997

# %%
qcom.describe()
# Out:
#               High          Low         Open        Close        Volume  \
# count  4427.000000  4427.000000  4427.000000  4427.000000  4.427000e+03
# mean     59.609799    58.239491    58.923218    58.934153  1.446972e+07
# std      24.010172    23.492313    23.776353    23.746494  8.733311e+06
# min      27.400000    26.665001    26.750000    26.809999  2.120200e+06
# 25%      43.065001    42.020000    42.509998    42.529999  9.079400e+06
# 50%      55.000000    53.810001    54.450001    54.459999  1.258070e+07
# 75%      67.639999    66.365002    67.000000    66.985001  1.729750e+07
# max     167.940002   164.440002   167.580002   164.779999  1.560193e+08
#
#          Adj Close
# count  4427.000000
# mean     48.833026
# std      26.093992
# min      18.431419
# 25%      30.340551
# 50%      44.427731
# 75%      56.685640
# max     163.165833

# %%
intc.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000
# mean    54.582778   55.273571   53.941349   54.583413   54.080949
# std      5.790522    5.903613    5.628452    5.780326    5.963053
# min     44.099998   44.470001   43.610001   44.110001   43.260830
# 25%     49.705001   50.225000   49.157498   49.727500   48.973809
# 50%     54.700001   55.675001   54.159999   55.005001   54.802765
# 75%     58.165001   58.480000   57.275002   57.990002   57.753464
# max     68.199997   68.489998   66.629997   68.260002   67.842155
#
#              Volume
# count  2.520000e+02
# mean   3.209863e+07
# std    1.538645e+07
# min    1.186560e+07
# 25%    2.231838e+07
# 50%    2.872085e+07
# 75%    3.552898e+07
# max    1.240707e+08

# %%
intc.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
amd.columns
# Out:
# Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
ibm.columns
# Out:
# Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
qcom.columns
# Out:
# Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
nvda.index
# Out:
# DatetimeIndex(['2003-12-31', '2004-01-02', '2004-01-05', '2004-01-06',
#                '2004-01-07', '2004-01-08', '2004-01-09', '2004-01-12',
#                '2004-01-13', '2004-01-14',
#                ...
#                '2021-07-20', '2021-07-21', '2021-07-22', '2021-07-23',
#                '2021-07-26', '2021-07-27', '2021-07-28', '2021-07-29',
#                '2021-07-30', '2021-08-02'],
#               dtype='datetime64[ns]', name='Date', length=4427, freq=None)

# %%
intc.index
# Out:
# DatetimeIndex(['2020-08-03', '2020-08-04', '2020-08-05', '2020-08-06',
#                '2020-08-07', '2020-08-10', '2020-08-11', '2020-08-12',
#                '2020-08-13', '2020-08-14',
#                ...
#                '2021-07-20', '2021-07-21', '2021-07-22', '2021-07-23',
#                '2021-07-26', '2021-07-27', '2021-07-28', '2021-07-29',
#                '2021-07-30', '2021-08-02'],
#               dtype='datetime64[ns]', name='Date', length=252, freq=None)

# %%
nvda.shape
# Out:
# (4427, 6)

# %% [markdown]
# # Time Series data

# %% [raw]
# A time series is a sequence of numerical data taken at successive equally spaced points in time. In investing a time series track the movement of stock price, over a specific period of time.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.dates as mdates

# %%
plt.plot(ibm.index, ibm['Adj Close'])
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
#plt.grid(True)
plt.xticks(rotation=90)
plt.title('IBM Stocks Prediction')
plt.show()

# %% [markdown]
# # Subplot

# %%
f, ax=plt.subplots(2,2, figsize=(10,10), sharex=True)
f.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
f.gca().xaxis.set_major_locator(mdates.YearLocator())

ax[0,0].plot(nvda.index, nvda['Adj Close'], color='r')
ax[0,0].grid(True)
ax[0,0].tick_params(labelrotation=90)
ax[0,0].set_title('NVDA');

ax[0,1].plot(amd.index, amd['Adj Close'], color='g')
ax[0,1].grid(True)
ax[0,1].tick_params(labelrotation=90)
ax[0,1].set_title('AMD');

ax[1,0].plot(intc.index, intc['Adj Close'], color='b')
ax[1,0].grid(True)
ax[1,0].tick_params(labelrotation=90)
ax[1,0].set_title('INTC');

ax[1,1].plot(qcom.index, qcom['Adj Close'], color='y')
ax[1,1].grid(True)
ax[1,1].tick_params(labelrotation=90)
ax[1,1].set_title('QCOM');

# %% [markdown]
# # Zooming-in

# %%
ibm_18=ibm.loc[pd.Timestamp('2018-01-01'):pd.Timestamp('2018-12-31')]
plt.plot(ibm_18.index, ibm_18['Adj Close'])
plt.grid(True)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # sublpots

# %%
f, ax=plt.subplots(2,2, figsize=(10,10), sharex=True, sharey=True)
f.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
f.gca().xaxis.set_major_locator(mdates.YearLocator())

nvda_18=nvda.loc[pd.Timestamp('2000-01-01'):pd.Timestamp('2018-12-31')]
ax[0,0].plot(nvda.index, nvda['Adj Close'], color='r')
ax[0,0].grid(True)
ax[0,0].tick_params(labelrotation=90)
ax[0,0].set_title('NVDA');

amd_18=amd.loc[pd.Timestamp('2000-01-01'):pd.Timestamp('2018-12-31')]
ax[0,1].plot(amd.index, amd['Adj Close'], color='g')
ax[0,1].grid(True)
ax[0,1].tick_params(labelrotation=90)
ax[0,1].set_title('AMD');

intc_18=intc.loc[pd.Timestamp('2000-01-01'):pd.Timestamp('2018-12-31')]
ax[1,0].plot(intc.index, intc['Adj Close'], color='b')
ax[1,0].grid(True)
ax[1,0].tick_params(labelrotation=90)
ax[1,0].set_title('INTC');

qcom_18=qcom.loc[pd.Timestamp('2000-01-01'):pd.Timestamp('2018-12-31')]
ax[1,1].plot(qcom.index, qcom['Adj Close'], color='y')
ax[1,1].grid(True)
ax[1,1].tick_params(labelrotation=90)
ax[1,1].set_title('QCOM');

# %% [markdown]
# # step 2: Resampling (Quarterly)

# %%
monthly_nvda_18=nvda_18.resample('4M').mean()
plt.scatter(monthly_nvda_18.index, monthly_nvda_18['Adj Close'])
plt.grid(True)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # sub plots

# %%
f, ax=plt.subplots(2,2, figsize=(10,10), sharex=True, sharey=True)
f.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
f.gca().xaxis.set_major_locator(mdates.YearLocator())

monthly_ibm_18=ibm_18.resample('4M').mean()
ax[0,0].scatter(monthly_ibm_18.index, monthly_ibm_18['Adj Close'], color='r')
ax[0,0].grid(True)
ax[0,0].tick_params(labelrotation=90)
ax[0,0].set_title('IBM');

monthly_amd_18=amd_18.resample('4M').mean()
ax[0,1].scatter(monthly_amd_18.index, monthly_amd_18['Adj Close'], color='g')
ax[0,1].grid(True)
ax[0,1].tick_params(labelrotation=90)
ax[0,1].set_title('AMD');

monthly_intc_18=intc_18.resample('4M').mean()
ax[1,0].plot(monthly_intc_18.index, monthly_intc_18['Adj Close'], color='b')
ax[1,0].grid(True)
ax[1,0].tick_params(labelrotation=90)
ax[1,0].set_title('INTC');

monthly_qcom_18=qcom_18.resample('4M').mean()
ax[1,1].scatter(monthly_qcom_18.index, monthly_qcom_18['Adj Close'], color='y')
ax[1,1].grid(True)
ax[1,1].tick_params(labelrotation=90)
ax[1,1].set_title('QCOM');

# %% [markdown]
# # Step 3: Resampling (Weekly)

# %%
ibm_21=ibm.loc[pd.Timestamp('2021-01-01'):pd.Timestamp('2021-08-02')]

# %%
weekly_ibm_21=ibm_21.resample('W').mean()
weekly_ibm_21.head()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2021-01-10  128.852003  125.922000  127.274001  127.378000   5686820.0
# 2021-01-17  129.736002  127.456001  128.497998  128.414001   5887500.0
# 2021-01-24  128.397499  126.014999  127.449997  127.340000  15399850.0
# 2021-01-31  122.284000  119.292000  120.608002  120.546001  11287440.0
# 2021-02-07  120.931999  119.104001  119.842001  120.382001   5687120.0
#
#              Adj Close
# Date
# 2021-01-10  124.309378
# 2021-01-17  125.320422
# 2021-01-24  124.272295
# 2021-01-31  117.641965
# 2021-02-07  117.481917

# %%
plt.plot(weekly_ibm_21.index, weekly_ibm_21['Adj Close'], '-o')
plt.grid(True)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=90)
plt.show()

# %%
nvda_21=nvda.loc[pd.Timestamp('2021-01-01'):pd.Timestamp('2021-08-02')]
weekly_nvda_21=nvda_21.resample('W').mean()

amd_21=amd.loc[pd.Timestamp('2021-01-01'):pd.Timestamp('2021-08-02')]
weekly_amd_21=amd_21.resample('W').mean()

intc_21=intc.loc[pd.Timestamp('2021-01-01'):pd.Timestamp('2021-08-02')]
weekly_intc_21=intc_21.resample('W').mean()

qcom_21=qcom.loc[pd.Timestamp('2021-01-01'):pd.Timestamp('2021-08-02')]
weekly_qcom_21=qcom_21.resample('W').mean()

# %% [markdown]
# # Subplots

# %%
f, ax=plt.subplots(2,2, figsize=(10,10), sharex=True, sharey=True)
#f.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
#f.gca().xaxis.set_major_locator(mdates.MonthLocator())

weekly_nvda_21=nvda_21.resample('W').mean()
ax[0,0].plot(weekly_nvda_21.index, weekly_nvda_21['Adj Close'], color='r')
ax[0,0].grid(True)
ax[0,0].tick_params(labelrotation=90)
ax[0,0].set_title('NVIDIA');

weekly_amd_21=amd_21.resample('4M').mean()
ax[0,1].plot(weekly_amd_21.index, weekly_amd_21['Adj Close'], color='g')
ax[0,1].grid(True)
ax[0,1].tick_params(labelrotation=90)
ax[0,1].set_title('AMD');

weekly_intc_21=intc_21.resample('W').mean()
ax[1,0].plot(weekly_intc_21.index, weekly_intc_21['Adj Close'], color='b')
ax[1,0].grid(True)
ax[1,0].tick_params(labelrotation=90)
ax[1,0].set_title('INTC');

weekly_qcom_21=qcom_21.resample('4M').mean()
ax[1,1].plot(weekly_qcom_21.index, weekly_qcom_21['Adj Close'], color='y')
ax[1,1].grid(True)
ax[1,1].tick_params(labelrotation=90)
ax[1,1].set_title('QCOM');

# %% [markdown]
# # Analysing Difference between levels (Resampling weekly)

# %%
ibm['diff']=ibm['Open'] - ibm['Close']
ibm_diff=ibm.resample('W').mean()
ibm_diff.tail(10)
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 2021-06-06  146.252502  144.414997  145.132500  145.720001  3113225.0
# 2021-06-13  150.940002  148.847998  149.319998  149.916000  4408580.0
# 2021-06-20  148.687997  146.560001  148.470001  147.188000  4652180.0
# 2021-06-27  146.700000  144.724002  145.648001  145.979999  3425800.0
# 2021-07-04  147.084000  144.150006  146.254001  144.857999  5811960.0
# 2021-07-11  141.009998  138.590000  139.494999  140.215004  5386075.0
# 2021-07-18  141.018002  139.213998  140.678000  140.073999  3730720.0
# 2021-07-25  141.662000  139.060001  140.408002  140.248001  6957280.0
# 2021-08-01  142.910004  141.352002  142.156000  142.036002  3226520.0
# 2021-08-08  143.059998  141.029999  141.449997  141.419998  2928900.0
#
#              Adj Close      diff
# Date
# 2021-06-06  145.720001 -0.587502
# 2021-06-13  149.916000 -0.596002
# 2021-06-20  147.188000  1.282001
# 2021-06-27  145.979999 -0.331998
# ...

# %%
plt.scatter(ibm_diff.loc['2021-01-01':'2021-08-01'].index, ibm_diff.loc['2021-01-01':'2021-08-01']['diff'])
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # sub Pots

# %%
nvda['diff']=nvda['Open'] - nvda['Close']
nvda_diff=nvda.resample('W').mean()

intc['diff']=intc['Open'] - intc['Close']
intc_diff=intc.resample('W').mean()

amd['diff']=amd['Open'] - amd['Close']
amd_diff=amd.resample('W').mean()

qcom['diff']=qcom['Open'] - qcom['Close']
qcom_diff=qcom.resample('W').mean()

# %%
f, ax=plt.subplots(2,2, figsize=(10,10), sharex=True, sharey=True)
#f.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
#f.gca().xaxis.set_major_locator(mdates.MonthLocator())

ax[0,0].scatter(nvda_diff.loc['2021-01-01':'2021-08-01'].index, nvda_diff.loc['2021-01-01':'2021-08-01']['diff'], color='r')
ax[0,0].grid(True)
ax[0,0].tick_params(labelrotation=90)
ax[0,0].set_title('NVIDIA');

ax[0,1].scatter(amd_diff.loc['2021-01-01':'2021-08-01'].index, amd_diff.loc['2021-01-01':'2021-08-01']['diff'], color='b')
ax[0,1].grid(True)
ax[0,1].tick_params(labelrotation=90)
ax[0,1].set_title('AMD');

ax[1,0].scatter(intc_diff.loc['2021-01-01':'2021-08-01'].index, intc_diff.loc['2021-01-01':'2021-08-01']['diff'], color='g')
ax[1,0].grid(True)
ax[1,0].tick_params(labelrotation=90)
ax[1,0].set_title('INTC');

ax[1,1].scatter(qcom_diff.loc['2021-01-01':'2021-08-01'].index, qcom_diff.loc['2021-01-01':'2021-08-01']['diff'], color='y')
ax[1,1].grid(True)
ax[1,1].tick_params(labelrotation=90)
ax[1,1].set_title('QCOM');

# %% [markdown]
# # Step 4: Moving Windows

# %%
daily_close_ibm=ibm[['Adj Close']]

# daily return
daily_pct_change_ibm=daily_close_ibm.pct_change()

# Replace NA values with 0
daily_pct_change_ibm.fillna(0, inplace=True)

daily_pct_change_ibm.head()
# Out:
#             Adj Close
# Date
# 2003-12-31   0.000000
# 2004-01-02  -0.012192
# 2004-01-05   0.016384
# 2004-01-06   0.000108
# 2004-01-07  -0.003009

# %%
daily_pct_change_ibm.hist(bins=50)

plt.show()

# %%
daily_close_nvda=ibm[['Adj Close']]
# daily return
daily_pct_change_nvda=daily_close_nvda.pct_change()
# Replace NA values with 0
daily_pct_change_nvda.fillna(0, inplace=True)
daily_pct_change_nvda.head()


daily_close_amd=amd[['Adj Close']]
# daily return
daily_pct_change_amd=daily_close_amd.pct_change()
# Replace NA values with 0
daily_pct_change_amd.fillna(0, inplace=True)


daily_close_intc=intc[['Adj Close']]
# daily return
daily_pct_change_intc=daily_close_intc.pct_change()
# Replace NA values with 0
daily_pct_change_intc.fillna(0, inplace=True)


daily_close_qcom=qcom[['Adj Close']]
# daily return
daily_pct_change_qcom=daily_close_qcom.pct_change()
# Replace NA values with 0
daily_pct_change_qcom.fillna(0, inplace=True)
daily_pct_change_qcom.head()
# Out:
#             Adj Close
# Date
# 2003-12-31   0.000000
# 2004-01-02  -0.005748
# 2004-01-05   0.021075
# 2004-01-06  -0.009498
# 2004-01-07   0.028213

# %%
import seaborn as sns
sns.set()

# %%
import seaborn as sns
f, axes=plt.subplots(2,2, figsize=(12,7))

# plot a simple histogram with binsize determined automatically
sns.distplot(daily_pct_change_nvda['Adj Close'], color="r", ax=axes[0,0], axlabel='NVIDIA');

# Plot a kernal density estimate and rug plot
sns.distplot(daily_pct_change_amd['Adj Close'], color="b", ax=axes[0,1], axlabel='AMD');

# Plot a filled kernal density estimate
sns.distplot(daily_pct_change_intc['Adj Close'], color="g", ax=axes[1,0], axlabel='INTEL');

# Plot a histogram and kernal density estimate
sns.distplot(daily_pct_change_qcom['Adj Close'], color="y", ax=axes[1,1], axlabel='QCOM');
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# # Step 4: Volatality

# %%
import numpy as np

# %%
min_periods=75

#calculate the volatality
vol=daily_pct_change_ibm.rolling(min_periods).std()*np.sqrt(min_periods)
vol.fillna(0, inplace=True)
vol.tail()
# Out:
#             Adj Close
# Date
# 2021-07-27   0.111021
# 2021-07-28   0.110902
# 2021-07-29   0.107661
# 2021-07-30   0.107500
# 2021-08-02   0.107513

# %%
# Plot the volatality
vol.plot(figsize=(10,8))

#show the plot
plt.show()

# %% [markdown]
# # Rolling Means (Trends and Seasonality)

# %%
ibm_adj_close_px=ibm['Adj Close']

# Short moving window rolling mean
ibm['42']=ibm_adj_close_px.rolling(window=40).mean()
# long moving window rolling mean
ibm['252']=ibm_adj_close_px.rolling(window=252).mean()
# Plot the adjusted closing price, the short and long window of rolling means
ibm[['Adj Close', '42', '252']].plot(title="IBM")
# show plot
plt.show()



nvda_adj_close_px=nvda['Adj Close']
# Short moving window rolling mean
nvda['42']=nvda_adj_close_px.rolling(window=40).mean()
# long moving window rolling mean
nvda['252']=nvda_adj_close_px.rolling(window=252).mean()
# Plot the adjusted closing price, the short and long window of rolling means
nvda[['Adj Close', '42', '252']].plot(title="NVDIA")
# show plot
plt.show()


amd_adj_close_px=amd['Adj Close']
# Short moving window rolling mean
amd['42']=amd_adj_close_px.rolling(window=40).mean()
# long moving window rolling mean
amd['252']=amd_adj_close_px.rolling(window=252).mean()
# Plot the adjusted closing price, the short and long window of rolling means
amd[['Adj Close', '42', '252']].plot(title="AMD")
# show plot
plt.show()


intc_adj_close_px=intc['Adj Close']
# Short moving window rolling mean
intc['42']=intc_adj_close_px.rolling(window=40).mean()
# long moving window rolling mean
intc['252']=intc_adj_close_px.rolling(window=252).mean()
# Plot the adjusted closing price, the short and long window of rolling means
intc[['Adj Close', '42', '252']].plot(title="INTC")
# show plot
plt.show()


qcom_adj_close_px=qcom['Adj Close']
# Short moving window rolling mean
qcom['42']=qcom_adj_close_px.rolling(window=40).mean()
# long moving window rolling mean
qcom['252']=qcom_adj_close_px.rolling(window=252).mean()
# Plot the adjusted closing price, the short and long window of rolling means
qcom[['Adj Close', '42', '252']].plot(title="QCOM")
# show plot
plt.show()

# %%
ibm.loc['2021-01-21':'2021-08-01'][['Adj Close','42', '252']].plot(title="IBM in 2021");
nvda.loc['2021-01-21':'2021-08-01'][['Adj Close','42', '252']].plot(title="VNDIA in 2021");
amd.loc['2021-01-21':'2021-08-01'][['Adj Close','42', '252']].plot(title="AMD in 2021");
intc.loc['2021-01-21':'2021-08-01'][['Adj Close','42', '252']].plot(title="INTEL in 2021");
qcom.loc['2021-01-21':'2021-08-01'][['Adj Close','42', '252']].plot(title="QCOM in 2021");
